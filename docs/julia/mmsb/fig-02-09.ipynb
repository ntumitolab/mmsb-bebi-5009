# %% [markdown]
# # Fig 2.09
#
# Numerical Simulation of a metabolic network

# %%
using DifferentialEquations
using Catalyst
using ModelingToolkit
using Plots
Plots.gr(lw=2)
# Out:
# Plots.GRBackend()

# %%
# Convenience functions
hill(x, k) = x / (x + k)
hill(x, k, n) = hill(x^n, k^n)
# Out:
# hill (generic function with 2 methods)

# %%
# Model building
net = @reaction_network begin
    3.0, ∅ --> A
    2.0, A --> B
    2.5, A + B --> C + D
    3.0, C --> ∅
    3.0, D --> ∅
end
# Out:
# Model ##ReactionSystem#257 with 5 equations
# States (4):
#   A(t)
#   B(t)
#   C(t)
#   D(t)
# Parameters (0):

# %%
odesys = convert(ODESystem, net)
# Out:
# Model ##ReactionSystem#257 with 4 equations
# States (4):
#   A(t)
#   B(t)
#   C(t)
#   D(t)
# Parameters (0):

# %%
speciesmap(net)
# Out:
# Dict{Term{Real, Base.ImmutableDict{DataType, Any}}, Int64} with 4 entries:
#   B(t) => 2
#   A(t) => 1
#   C(t) => 3
#   D(t) => 4

# %%
u0 = zeros(4)
tend = 10.0
sol = solve(ODEProblem(net, u0, tend))
# Out:
# retcode: Success
# Interpolation: automatic order switching interpolation
# t: 30-element Vector{Float64}:
#   0.0
#   9.999999999999999e-5
#   0.0010999999999999998
#   0.011099999999999997
#   0.03416738935703762
#   0.06493821924885028
#   0.1012934199992325
#   0.14525433637251192
#   0.1981966546957134
#   0.2628662838587544
#   0.341974143511255
#   0.4408076884404768
#   0.5771314686420985
#   ⋮
#   1.830014671103413
#   2.197707162483783
#   2.5929224915179367
#   3.0709879982662214
#   3.6350045228986136
#   4.345025617959607
#   5.23647341986066
#   6.330694531187695
#   7.484380148952406
#   8.528825781355344
#   9.4477579039105
#  10.0
# u: 30-element Vector{Vector{Float64}}:
#  [0.0, 0.0, 0.0, 0.0]
#  [0.00029997000199933764, 2.999799953754866e-8, 5.623912546644786e-16, 5.623912546644786e-16]
#  [0.003296372652316679, 3.627331236355826e-6, 8.21805646090172e-12, 8.21805646090172e-12]
#  [0.0329330063952576, 0.00036682535223159706, 8.356768013816546e-8, 8.356768013816546e-8]
#  [0.09907115088224092, 0.0034163858957268803, 7.16703271830343e-6, 7.16703271830343e-6]
#  [0.1826051333283312, 0.012026884125403823, 8.782075229051208e-5, 8.782075229051208e-5]
#  [0.27458558236887015, 0.02827140674363192, 0.0004812985396527545, 0.0004812985396527545]
#  [0.3762756608768443, 0.055455742267569566, 0.0018458579491216192, 0.0018458579491216192]
#  [0.4850085486878384, 0.09682258380927386, 0.005651816053508157, 0.005651816053508157]
#  [0.5976299320193224, 0.1559380898797703, 0.014887532366566932, 0.014887532366566932]
#  [0.706054202181548, 0.2341313098018648, 0.03456311104027852, 0.03456311104027852]
#  [0.7999346445997305, 0.3306157053951748, 0.07214326209225344, 0.07214326209225344]
#  [0.8680990384446576, 0.44735761026097265, 0.14105843331298398, 0.14105843331298398]
#  ⋮
#  [0.7748671513725746, 0.774110631109327, 0.4856906955449778, 0.4856906955449778]
#  [0.7620056821945196, 0.7872154077031535, 0.49517256564330125, 0.49517256564330125]
#  [0.755543607309428, 0.7939561550915055, 0.4984392970469585, 0.4984392970469585]
#  [0.752211966084403, 0.7975437685248135, 0.4995586109313673, 0.4995586109313673]
#  [0.7507598164766807, 0.7991477430101603, 0.4998822595757259, 0.4998822595757259]
#  [0.7502017039680705, 0.7997737763500886, 0.4999709580977103, 0.4999709580977103]
#  [0.7500411300629162, 0.7999559299140169, 0.49999058634839155, 0.49999058634839155]
#  [0.750015485826303, 0.7999931395182326, 0.49998007708099124, 0.49998007708099124]
#  [0.7500569878040357, 0.799998948261916, 0.49988743496613747, 0.49988743496613747]
#  [0.750173859013559, 0.7999998318089834, 0.49965239428213043, 0.49965239428213043]
#  [0.7502344571146677, 0.7999999687171588, 0.4995310948787499, 0.4995310948787499]
#  [0.7500362351228198, 0.799999988885352, 0.4999275397929294, 0.4999275397929294]

# %%
plot(sol, xlims=(0.0, 4.0), ylims=(0.0, 1.0), 
     xlabel="Time (sec)", ylabel="Concentration (mM)", title="Figure 2.09",
     legend=:bottomright)
