# %% [markdown]
# # Figure 3.03 Michaelis-Menten kinetics

# %%
using DifferentialEquations
using ModelingToolkit
using Plots
Plots.gr(lw=2)
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1342
# Plots.GRBackend()

# %%
hill(x, k) = x / (x + k)
hill(x, k, n) = hill(x^n, k^n)
# Out:
# hill (generic function with 2 methods)

# %%
@parameters eT k1 km1 k2
@variables t S(t) ES(t) P(t) eFree(t) v1(t) v2(t)
D = Differential(t)
# Out:
# (::Differential) (generic function with 2 methods)

# %%
@named fullSys = ODESystem([
    eFree ~ eT - ES,
    v1 ~ k1 * S * eFree - km1 * ES,
    v2 ~ k2 * ES,
    D(S) ~ -v1,
    D(ES) ~ v1 - v2,
    D(P) ~ v2
])
# Out:
# Model fullSys with 6 equations
# States (6):
#   S(t)
#   ES(t)
#   P(t)
#   eFree(t)
#   v1(t)
#   v2(t)
# Parameters (4):
#   eT
#   km1
#   k1
#   k2

# %%
fullSys = structural_simplify(fullSys)
# Out:
# Model fullSys with 3 equations
# States (3):
#   S(t)
#   ES(t)
#   P(t)
# Parameters (4):
#   eT
#   km1
#   k1
#   k2
# Incidence matrix:
#  ×  ⋅  ⋅  ×  ×  ⋅
#  ⋅  ×  ⋅  ×  ×  ⋅
#  ⋅  ⋅  ×  ⋅  ×  ⋅

# %%
# Apply QSSA on the ES complex to somplify the model
@named simpSys = ODESystem([
    D(S) ~ -k2 * eT * hill(S, (km1 + k2) / k1),
])
# Out:
# Model simpSys with 1 equations
# States (1):
#   S(t)
# Parameters (4):
#   km1
#   k1
#   eT
#   k2

# %%
u0 = [S => 5.0, ES => 0.0, P => 0.0]
tend = 1.0
params = [eT => 1.0, k1 => 30.0, km1 => 1.0, k2 => 10.0]
sol = solve(ODEProblem(fullSys, u0, tend, params))
# Out:
# retcode: Success
# Interpolation: automatic order switching interpolation
# t: 40-element Vector{Float64}:
#  0.0
#  6.665333466693315e-6
#  7.331866813362645e-5
#  0.000486426530181811
#  0.0012463105335874984
#  0.002255916533051079
#  0.0036389201205414856
#  0.0054558339005407915
#  0.007824958909241769
#  0.01084076598994703
#  0.0146219019713246
#  0.01927740163785426
#  0.024945076627481008
#  ⋮
#  0.4852116362040185
#  0.5402010718115909
#  0.5962934709931191
#  0.6498572095496072
#  0.6992361018633796
#  0.7455746779351546
#  0.7903699070118637
#  0.8349925600307094
#  0.8806909882547767
#  0.928657896443503
#  0.9801091431656057
#  1.0
# u: 40-element Vector{Vector{Float64}}:
#  [5.0, 0.0, 0.0]
#  [4.999000802751873, 0.000999163942258781, 3.330586857606658e-8]
#  [4.989074749914229, 0.010921237104096313, 4.012981675171874e-6]
#  [4.930127941487401, 0.0696999425627043, 0.00017211594989572642]
#  [4.83222624731284, 0.16669488457593237, 0.0010788681112279999]
#  [4.720095581033622, 0.2765713220296976, 0.00333309693668064]
#  [4.593086932342045, 0.3988758939815088, 0.008037173676445863]
#  [4.461543531353349, 0.521998093864313, 0.01645837478233783]
#  [4.332646099003416, 0.6370812525407338, 0.03027264845585039]
#  [4.214625764625098, 0.7343117687370342, 0.05106246663786781]
#  [4.111199807894063, 0.8084431605725165, 0.08035703153342054]
#  [4.022104112722738, 0.8586065039901403, 0.1192893832871209]
#  [3.9427301501433996, 0.8883631992097727, 0.16890665064682753]
#  ⋮
#  [0.4330973296796666, 0.6154853302489647, 3.9514173400713686]
#  [0.23210795725639347, 0.5069091123211213, 4.260982930422485]
#  [0.10688427161544334, 0.38244106352953205, 4.510674664855024]
#  [0.04626417076271447, 0.26918686630606226, 4.684548962931223]
#  [0.020977130304226606, 0.18357584129212728, 4.795447028403646]
#  [0.010414961763856227, 0.12369164138727466, 4.865893396848869]
#  [0.00565647369341302, 0.08276254754881637, 4.911580978757771]
#  [0.0032796770572542013, 0.05484220773927032, 4.941878115203475]
#  [0.0019694276930328587, 0.03575370810444151, 4.962276864202526]
#  [0.0011916718331211312, 0.02273526996963047, 4.976073058197248]
#  [0.0007101814733151397, 0.013958554049061041, 4.985331264477623]
#  [0.0005834152167996266, 0.011555343088919217, 4.98786124169428]

# %%
p1 = plot(sol, vars=[S, ES, P, eFree], xlabel="Time (AU)", ylabel="Concentration (AU)", legend=:right)

# %%
solsimp = solve(ODEProblem(simpSys, u0, tend, params))
# Out:
# retcode: Success
# Interpolation: automatic order switching interpolation
# t: 15-element Vector{Float64}:
#  0.0
#  0.08829951015219592
#  0.29677254913999207
#  0.500000468671217
#  0.6196473837012987
#  0.667010430092469
#  0.7099274959046816
#  0.7465737429986002
#  0.7827003061957977
#  0.8170029037689358
#  0.851532481230377
#  0.8866728238828602
#  0.9240248948050929
#  0.9646817032350656
#  1.0
# u: 15-element Vector{Vector{Float64}}:
#  [5.0]
#  [4.182468228248958]
#  [2.3146741513235356]
#  [0.7140967899079597]
#  [0.13296506121927512]
#  [0.046302524580241256]
#  [0.01563176613015049]
#  [0.005910626885835261]
#  [0.0022299125570656034]
#  [0.0008784938222887489]
#  [0.00034320151568757197]
#  [0.00013175532009879323]
#  [4.761597847782403e-5]
#  [1.5733015129580863e-5]
#  [6.0074984477308984e-6]

# %%
p2 = plot(sol, vars=[1, 3], line=(:dash), label=["S (full)" "P (full)"])
plot!(p2, solsimp, line=(:blue), lab="S (reduced)")
plot!(p2, solsimp, vars=((t, s)->(t, 5.0 - s), 0, 1), line=(:red), lab="P (reduced)")
plot!(p2, xlabel="Time (AU)",  ylabel="Concentration (AU)", xlims=(0.0,1.0), ylims=(0.0,5.0), legend = :right)
