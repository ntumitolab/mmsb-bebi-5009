# %% [markdown]
# # Runtime information

# %%
import Pkg
Pkg.status()
# Out:
# Status `~/actions-runner-2/_work/mmsb-bebi-5009/mmsb-bebi-5009/Project.toml`
#   [336ed68f] CSV v0.10.15
#   [479239e8] Catalyst v14.4.1
#   [a93c6f00] DataFrames v1.7.0
#   [82cc6244] DataInterpolations v7.2.0
#   [459566f4] DiffEqCallbacks v4.3.0
#   [0b91fe84] DisplayAs v0.1.6
#   [31c24e10] Distributions v0.25.117
#   [f6369f11] ForwardDiff v0.10.38
#   [ccbc3e58] JumpProcesses v9.14.2
#   [961ee093] ModelingToolkit v9.64.3
#   [1dea7af3] OrdinaryDiffEq v6.91.0
#   [91a5bcdd] Plots v1.40.9
#   [ce78b400] SimpleUnPack v1.1.0
#   [10745b16] Statistics v1.11.1
#   [2913bbd2] StatsBase v0.34.4
#   [9672c7b4] SteadyStateDiffEq v2.4.1
#   [9a3f8284] Random v1.11.0

# %%
import InteractiveUtils
InteractiveUtils.versioninfo()
# Out:
# Julia Version 1.11.3
# Commit d63adeda50d (2025-01-21 19:42 UTC)
# Build Info:
#   Official https://julialang.org/ release
# Platform Info:
#   OS: Linux (x86_64-linux-gnu)
#   CPU: 12 × Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz
#   WORD_SIZE: 64
#   LLVM: libLLVM-16.0.6 (ORCJIT, skylake)
# Threads: 2 default, 0 interactive, 1 GC (on 12 virtual cores)
# Environment:
#   JULIA_CI = true
#   LD_LIBRARY_PATH = /home/github/actions-runner-2/_work/_tool/Python/3.13.2/x64/lib
#   JULIA_NUM_THREADS = 2
#   JULIA_PROJECT = /home/github/actions-runner-2/_work/mmsb-bebi-5009/mmsb-bebi-5009/Project.toml
#   JULIA_DEPOT_PATH = /home/github/.julia:/home/github/actions-runner-2/_work/_tool/julia/1.11.3/x64/local/share/julia:/home/github/actions-runner-2/_work/_tool/julia/1.11.3/x64/share/julia
#   JULIA_CONDAPKG_BACKEND = Null
#   JULIA_LOAD_PATH = @:@v#.#:@stdlib

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
